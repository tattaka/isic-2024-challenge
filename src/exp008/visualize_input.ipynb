# %%
from train import ISIC2024Dataset
import matplotlib.pyplot as plt 
import numpy as np
import pandas as pd
import h5py

# %%
train_meta_data = pd.read_csv("../../input/isic-2024-challenge/train-metadata.csv")
fold = pd.read_csv("../../input/isic-2024-challenge/fold.csv")
train_meta_data = train_meta_data.merge(fold, on="isic_id", how="inner")
train_images = h5py.File("../../input/isic-2024-challenge/train-image.hdf5", "r")
dataset = ISIC2024Dataset(
    train_meta_data,
    data=train_images,
    mode="train",
    image_size=256
)
# Out:
# /tmp/ipykernel_979606/1679956006.py:1: DtypeWarning: Columns (51,52) have mixed types. Specify dtype option on import or set low_memory=False.
#   train_meta_data = pd.read_csv("../../input/isic-2024-challenge/train-metadata.csv")

# %%
plt.imshow((dataset[0]["image"]).permute(1, 2, 0).numpy())
